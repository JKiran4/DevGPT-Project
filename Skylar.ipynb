# %%
import json
import pandas as pd
import altair as alt
from langdetect import detect
import re
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_paths = [
    '20231012_230826_commit_sharings.json',
    '20231012_232232_hn_sharings.json',
    '20231012_233628_pr_sharings.json',
    '20231012_234250_file_sharings.json',
    '20231012_235128_issue_sharings.json',
    '20231012_235320_discussion_sharings.json'
]

all_data = [] 

for file_path in file_paths:
    with open(file_path, 'r') as file:
        data = json.load(file)

        # first get embedded data from Sources column
        for source in data.get('Sources', []):
            source_type = source.get('Type', '')
            source_id = source.get('ID', '')
            source_url = source.get('URL', '')
            author = source.get('Author', '')
            title = source.get('Title', '')
            RepoName = source.get('RepoName', '')
            RepoLanguage = source.get('RepoLanguage', '')
            created_at = source.get('CreatedAt', '')

            # then get embedded data from ChatgptSharing column
            for chatgpt_sharing in source.get('ChatgptSharing', []):
                chatgpt_url = chatgpt_sharing.get('URL', '')
                status = chatgpt_sharing.get('Status', '')
                date_of_conversation = chatgpt_sharing.get('DateOfConversation', '')
                date_of_access = chatgpt_sharing.get('DateOfAccess', '')
                model_used = chatgpt_sharing.get('Model', '')
                num_prompts = chatgpt_sharing.get('NumberOfPrompts', 0)
                tokens_of_prompts = chatgpt_sharing.get('TokensOfPrompts', 0)
                tokens_of_answers = chatgpt_sharing.get('TokensOfAnswers', 0)

                # lastly, exract the conversation information
                for conversation in chatgpt_sharing.get('Conversations', []):
                    entry = {
                        "SourceType": source_type,
                        "SourceID": source_id,
                        "SourceURL": source_url,
                        "Author": author,
                        "Title": title,
                        "RepoName": RepoName,
                        "RepoLanguage": RepoLanguage,
                        "CreatedAt": created_at,
                        "ChatGPT_URL": chatgpt_url,
                        "Status": status,
                        "DateOfConversation": date_of_conversation,
                        "DateOfAccess": date_of_access,
                        "ModelUsed": model_used,
                        "NumPrompts": num_prompts,
                        "TokensOfPrompts": tokens_of_prompts,
                        "TokensOfAnswers": tokens_of_answers,
                        "Prompt": conversation.get("Prompt", ""),
                        "Answer": conversation.get("Answer", ""),
                        "ListOfCode": conversation.get("ListOfCode", [])
                    }
                    all_data.append(entry)

df = pd.DataFrame(all_data)

# %%
df.columns
# Out:
# Index(['SourceType', 'SourceID', 'SourceURL', 'Author', 'Title', 'RepoName',
#        'RepoLanguage', 'CreatedAt', 'ChatGPT_URL', 'Status',
#        'DateOfConversation', 'DateOfAccess', 'ModelUsed', 'NumPrompts',
#        'TokensOfPrompts', 'TokensOfAnswers', 'Prompt', 'Answer', 'ListOfCode'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# SourceType               0
# SourceID                 0
# SourceURL                0
# Author                   0
# Title                    0
# RepoName                 0
# RepoLanguage          1882
# CreatedAt                0
# ChatGPT_URL              0
# Status                   0
# DateOfConversation       0
# DateOfAccess             0
# ModelUsed                0
# NumPrompts               0
# TokensOfPrompts          0
# TokensOfAnswers          0
# Prompt                   0
# Answer                   0
# ListOfCode               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27093 entries, 0 to 27092
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   SourceType          27093 non-null  object
#  1   SourceID            27093 non-null  object
#  2   SourceURL           27093 non-null  object
#  3   Author              27093 non-null  object
#  4   Title               27093 non-null  object
#  5   RepoName            27093 non-null  object
#  6   RepoLanguage        25211 non-null  object
#  7   CreatedAt           27093 non-null  object
#  8   ChatGPT_URL         27093 non-null  object
#  9   Status              27093 non-null  int64
#  10  DateOfConversation  27093 non-null  object
#  11  DateOfAccess        27093 non-null  object
#  12  ModelUsed           27093 non-null  object
#  13  NumPrompts          27093 non-null  int64
#  14  TokensOfPrompts     27093 non-null  int64
#  15  TokensOfAnswers     27093 non-null  int64
#  16  Prompt              27093 non-null  object
#  17  Answer              27093 non-null  object
#  18  ListOfCode          27093 non-null  object
# dtypes: int64(4), object(15)
# memory usage: 3.9+ MB

# %%
df[df.duplicated(["Prompt", "Answer"])]
# Out:
#        SourceType SourceID                                          SourceURL  \
# 18         commit           https://github.com/changchiyou/Github-Action-T...
# 19         commit           https://github.com/changchiyou/Github-Action-T...
# 141        commit           https://github.com/bulatkhu/programmierung-und...
# 142        commit           https://github.com/bulatkhu/programmierung-und...
# 150        commit           https://github.com/pbrudny/jobsforit-de/commit...
# ...           ...      ...                                                ...
# 27008  discussion           https://github.com/nv-morpheus/Morpheus/discus...
# 27009  discussion           https://github.com/nv-morpheus/Morpheus/discus...
# 27010  discussion           https://github.com/nv-morpheus/Morpheus/discus...
# 27011  discussion           https://github.com/nv-morpheus/Morpheus/discus...
# 27012  discussion           https://github.com/nv-morpheus/Morpheus/discus...
#
#             Author                                              Title  \
# 18     changchiyou
# 19     changchiyou
# 141       bulatkhu
# 142       bulatkhu
# 150        pbrudny
# ...            ...                                                ...
# 27008       nyck33  [DOC]: Can I use Morpheus without Blue Shield,...
# 27009       nyck33  [DOC]: Can I use Morpheus without Blue Shield,...
# 27010       nyck33  [DOC]: Can I use Morpheus without Blue Shield,...
# 27011       nyck33  [DOC]: Can I use Morpheus without Blue Shield,...
# 27012       nyck33  [DOC]: Can I use Morpheus without Blue Shield,...
#
#                                               RepoName RepoLanguage  \
# 18                      changchiyou/Github-Action-Test       Python
# 19                      changchiyou/Github-Action-Test       Python
# 141    bulatkhu/programmierung-und-programmiersprachen         Java
# 142    bulatkhu/programmierung-und-programmiersprachen         Java
# 150                               pbrudny/jobsforit-de          CSS
# ...                                                ...          ...
# 27008                             nv-morpheus/Morpheus       Python
# 27009                             nv-morpheus/Morpheus       Python
# 27010                             nv-morpheus/Morpheus       Python
# 27011                             nv-morpheus/Morpheus       Python
# 27012                             nv-morpheus/Morpheus       Python
#
#                   CreatedAt  \
# 18
# 19
# 141
# 142
# 150
# ...                     ...
# 27008  2023-09-21T10:52:30Z
# 27009  2023-09-21T10:52:30Z
# 27010  2023-09-21T10:52:30Z
# 27011  2023-09-21T10:52:30Z
# 27012  2023-09-21T10:52:30Z
#
#                                              ChatGPT_URL  Status  \
# 18     https://chat.openai.com/share/7cf2816f-13ea-40...     200
# 19     https://chat.openai.com/share/7cf2816f-13ea-40...     200
# 141    https://chat.openai.com/share/f082ae67-9f57-4a...     200
# 142    https://chat.openai.com/share/f082ae67-9f57-4a...     200
# 150    https://chat.openai.com/share/ba3847d4-8a7a-4f...     200
# ...                                                  ...     ...
# 27008  https://chat.openai.com/share/425a2879-ccfd-48...     200
# 27009  https://chat.openai.com/share/425a2879-ccfd-48...     200
# 27010  https://chat.openai.com/share/425a2879-ccfd-48...     200
# 27011  https://chat.openai.com/share/425a2879-ccfd-48...     200
# 27012  https://chat.openai.com/share/425a2879-ccfd-48...     200
#
#        DateOfConversation                DateOfAccess               ModelUsed  \
# 18        August 22, 2023  2023-10-12 23:53:36.382788       Default (GPT-3.5)
# 19        August 22, 2023  2023-10-12 23:53:36.382788       Default (GPT-3.5)
# 141    September 18, 2023  2023-10-12 23:54:03.002218  Advanced Data Analysis
# 142    September 18, 2023  2023-10-12 23:54:03.002218  Advanced Data Analysis
# 150    September 10, 2023  2023-10-12 23:54:09.877351                   GPT-4
# ...                   ...                         ...                     ...
# 27008  September 22, 2023  2023-10-12 23:52:43.916219  Advanced Data Analysis
# 27009  September 22, 2023  2023-10-12 23:52:43.916219  Advanced Data Analysis
# 27010  September 22, 2023  2023-10-12 23:52:43.916219  Advanced Data Analysis
# 27011  September 22, 2023  2023-10-12 23:52:43.916219  Advanced Data Analysis
# 27012  September 22, 2023  2023-10-12 23:52:43.916219  Advanced Data Analysis
#
#        NumPrompts  TokensOfPrompts  TokensOfAnswers  \
# 18              3              396              770
# 19              3              396              770
# 141             3             1040              766
# 142             3             1040              766
# 150             4             2525             1164
# ...           ...              ...              ...
# 27008          11              773             6413
# 27009          11              773             6413
# 27010          11              773             6413
# 27011          11              773             6413
# 27012          11              773             6413
#
#                                                   Prompt  \
# 18     i got \n\n```\n============================= t...
# 19     do i need to install `ptest`(not `pytest`) in ...
# 141    Composite-Muster\nDie Verzeichnisstruktur Ihre...
# 142    mach mir noch so eine aufgabe zu dem selben mu...
# 150    Seeing my package.json suggest updates which w...
# ...                                                  ...
# 27008  So can you write a Python driver that uses ext...
# 27009  ok, so correct me if I"m wrong but this is the...
# 27010  I think so but step 1 I think I might want to ...
# 27011  Can you write the code for these steps? ```Ste...
# 27012  Well based on what I showed you in the data.zi...
#
#                                                   Answer  \
# 18     ChatGPTIt looks like you're encountering an is...
# 19     ChatGPTYes, if your project relies on a module...
# 141    ChatGPTIhr Code implementiert das Composite-Mu...
# 142    ChatGPTNatürlich! Hier ist eine neue Aufgabe z...
# 150    ChatGPTYour package.json file lists a good num...
# ...                                                  ...
# 27008  ChatGPTCreating a Python driver to mimic the s...
# 27009  ChatGPTYou have the workflow largely correct. ...
# 27010  ChatGPTYou're correct; having continuous and r...
# 27011  ChatGPTSure! Let's start with a high-level ove...
# 27012  ChatGPTAbsolutely, based on the contents of da...
#
#                                               ListOfCode
# 18                                                    []
# 19     [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...
# 141                                                   []
# 142                                                   []
# 150                                                   []
# ...                                                  ...
# 27008  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...
# 27009                                                 []
# 27010                                                 []
# 27011  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...
# 27012  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...
#
# [8930 rows x 19 columns]

# %%
# noticed duplicate prompt/answer pairs, so remove these
df = df.drop_duplicates(subset = ["Prompt", "Answer"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18163 entries, 0 to 27092
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   SourceType          18163 non-null  object
#  1   SourceID            18163 non-null  object
#  2   SourceURL           18163 non-null  object
#  3   Author              18163 non-null  object
#  4   Title               18163 non-null  object
#  5   RepoName            18163 non-null  object
#  6   RepoLanguage        16497 non-null  object
#  7   CreatedAt           18163 non-null  object
#  8   ChatGPT_URL         18163 non-null  object
#  9   Status              18163 non-null  int64
#  10  DateOfConversation  18163 non-null  object
#  11  DateOfAccess        18163 non-null  object
#  12  ModelUsed           18163 non-null  object
#  13  NumPrompts          18163 non-null  int64
#  14  TokensOfPrompts     18163 non-null  int64
#  15  TokensOfAnswers     18163 non-null  int64
#  16  Prompt              18163 non-null  object
#  17  Answer              18163 non-null  object
#  18  ListOfCode          18163 non-null  object
# dtypes: int64(4), object(15)
# memory usage: 2.8+ MB

# %% [markdown]
# Time for some EDA

# %%
df.head()
# Out:
#   SourceType SourceID                                          SourceURL  \
# 0     commit           https://github.com/grnpin/textbox/commit/fa335...
# 1     commit           https://github.com/grnpin/textbox/commit/0dfc4...
# 2     commit           https://github.com/grnpin/textbox/commit/811d0...
# 3     commit           https://github.com/bh679/MindfulAI2.0/commit/e...
# 4     commit           https://github.com/bh679/MindfulAI2.0/commit/e...
#
#    Author Title            RepoName RepoLanguage CreatedAt  \
# 0  grnpin            grnpin/textbox         HTML
# 1  grnpin            grnpin/textbox         HTML
# 2  grnpin            grnpin/textbox         HTML
# 3   bh679        bh679/MindfulAI2.0          CSS
# 4   bh679        bh679/MindfulAI2.0          CSS
#
#                                          ChatGPT_URL  Status  \
# 0  https://chat.openai.com/share/4bad57dd-9636-4b...     200
# 1  https://chat.openai.com/share/1fd7ffc2-9264-45...     200
# 2  https://chat.openai.com/share/99d2d02f-7e3b-43...     200
# 3  https://chat.openai.com/share/90ebe55e-bd60-47...     200
# 4  https://chat.openai.com/share/90ebe55e-bd60-47...     200
#
#    DateOfConversation                DateOfAccess               ModelUsed  \
# 0  September 20, 2023  2023-10-12 23:53:27.348018       Default (GPT-3.5)
# 1   September 9, 2023  2023-10-12 23:53:27.833077                 Default
# 2   September 7, 2023  2023-10-12 23:53:28.345040                 Default
# 3      August 8, 2023  2023-10-12 23:53:29.830292  Advanced Data Analysis
# 4      August 8, 2023  2023-10-12 23:53:29.830292  Advanced Data Analysis
#
#    NumPrompts  TokensOfPrompts  TokensOfAnswers  \
# 0           1              330              556
# 1           1               51              160
# 2           1              916              115
# 3           6             5774             1898
# 4           6             5774             1898
#
#                                               Prompt  \
# 0  このコードだと、スマートフォンでキーボードを表示したときにbuttonがキーボードの下に隠れ...
# 1  このコードなんですが、Placeholder上でちゃんと改行するコードにできますか。\n\n...
# 2  refactor this code.\n\n<!DOCTYPE html>\n<html>...
# 3  server.js\n// Required libraries\nimport cors ...
# 4  package.json\n{\n  "name": "mindfulai",\n  "ve...
#
#                                               Answer  \
# 0  ChatGPTキーボードが表示されたときにボタンをキーボードの上に移動させるには、CSSでキ...
# 1  ChatGPTはい、改行を含むPlaceholder文字列を設定するコードを作成することがで...
# 2  ChatGPTHere's a refactored version of your HTM...
# 3  ChatGPTYou've shared multiple pieces of server...
# 4  ChatGPTIt looks like you're having issues with...
#
#                                           ListOfCode
# 0  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...

# %%
df.tail()
# Out:
#        SourceType SourceID                                          SourceURL  \
# 27088  discussion           https://github.com/ZoeLeBlanc/is578-intro-dh/d...
# 27089  discussion           https://github.com/ZoeLeBlanc/is578-intro-dh/d...
# 27090  discussion           https://github.com/ZoeLeBlanc/is578-intro-dh/d...
# 27091  discussion           https://github.com/ZoeLeBlanc/is578-intro-dh/d...
# 27092  discussion             https://github.com/orgs/netket/discussions/1482
#
#            Author                                              Title  \
# 27088  ZoeLeBlanc                                AI & CLI Assignment
# 27089  ZoeLeBlanc                                AI & CLI Assignment
# 27090  ZoeLeBlanc                                AI & CLI Assignment
# 27091  ZoeLeBlanc                                AI & CLI Assignment
# 27092   MrAAafa99  Exploring the Plotting of Pair Correlation Fun...
#
#                         RepoName RepoLanguage             CreatedAt  \
# 27088  ZoeLeBlanc/is578-intro-dh         HTML  2023-08-31T16:33:05Z
# 27089  ZoeLeBlanc/is578-intro-dh         HTML  2023-08-31T16:33:05Z
# 27090  ZoeLeBlanc/is578-intro-dh         HTML  2023-08-31T16:33:05Z
# 27091  ZoeLeBlanc/is578-intro-dh         HTML  2023-08-31T16:33:05Z
# 27092              netket/netket       Python  2023-05-25T15:11:27Z
#
#                                              ChatGPT_URL  Status  \
# 27088  https://chat.openai.com/share/cfe2a21a-29e0-47...     200
# 27089  https://chat.openai.com/share/cfe2a21a-29e0-47...     200
# 27090  https://chat.openai.com/share/cfe2a21a-29e0-47...     200
# 27091  https://chat.openai.com/share/cfe2a21a-29e0-47...     200
# 27092  https://chat.openai.com/share/caaa9e43-860a-46...     200
#
#       DateOfConversation                DateOfAccess          ModelUsed  \
# 27088  September 8, 2023  2023-10-12 23:53:17.501679  Default (GPT-3.5)
# 27089  September 8, 2023  2023-10-12 23:53:17.501679  Default (GPT-3.5)
# 27090  September 8, 2023  2023-10-12 23:53:17.501679  Default (GPT-3.5)
# 27091  September 8, 2023  2023-10-12 23:53:17.501679  Default (GPT-3.5)
# 27092    August 16, 2023  2023-10-12 23:53:19.322053  Default (GPT-3.5)
#
#        NumPrompts  TokensOfPrompts  TokensOfAnswers  \
# 27088           6              156             1830
# 27089           6              156             1830
# 27090           6              156             1830
# 27091           6              156             1830
# 27092           2               36              616
#
#                                                   Prompt  \
# 27088  received this error code when verifying the st...
# 27089  now create a how to use the command line to cr...
# 27090                   the echo command is not working
# 27091  the echo command is still not working on windo...
# 27092  how do I assign error bars to the entries of a...
#
#                                                   Answer  \
# 27088  ChatGPTI apologize for the confusion. It seems...
# 27089  ChatGPTTo create a text file with the content ...
# 27090  ChatGPTI apologize for the confusion. If the e...
# 27091  ChatGPTI apologize for the inconvenience. If t...
# 27092  ChatGPTAssigning error bars to histogram entri...
#
#                                               ListOfCode
# 27088  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...
# 27089  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...
# 27090  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...
# 27091  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...
# 27092  [{'ReplaceString': '[CODE_BLOCK_0]', 'Type': '...

# %%
df.describe()
# Out:
#         Status    NumPrompts  TokensOfPrompts  TokensOfAnswers
# count  18163.0  18163.000000     18163.000000     18163.000000
# mean     200.0     51.151462      8015.766228     16204.392556
# std        0.0    109.315835     24978.755346     28782.043523
# min      200.0      1.000000         4.000000         3.000000
# 25%      200.0      6.000000       382.000000      1808.000000
# 50%      200.0     17.000000      1311.000000      5704.000000
# 75%      200.0     42.000000      4901.000000     15075.000000
# max      200.0    574.000000    183736.000000    131131.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18163 entries, 0 to 27092
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   SourceType          18163 non-null  object
#  1   SourceID            18163 non-null  object
#  2   SourceURL           18163 non-null  object
#  3   Author              18163 non-null  object
#  4   Title               18163 non-null  object
#  5   RepoName            18163 non-null  object
#  6   RepoLanguage        16497 non-null  object
#  7   CreatedAt           18163 non-null  object
#  8   ChatGPT_URL         18163 non-null  object
#  9   Status              18163 non-null  int64
#  10  DateOfConversation  18163 non-null  object
#  11  DateOfAccess        18163 non-null  object
#  12  ModelUsed           18163 non-null  object
#  13  NumPrompts          18163 non-null  int64
#  14  TokensOfPrompts     18163 non-null  int64
#  15  TokensOfAnswers     18163 non-null  int64
#  16  Prompt              18163 non-null  object
#  17  Answer              18163 non-null  object
#  18  ListOfCode          18163 non-null  object
# dtypes: int64(4), object(15)
# memory usage: 2.8+ MB

# %% [markdown]
# Let's see how some of the data is distributed

# %%
df['Author'].value_counts()
# Out:
# Author
# bennyp85        776
# balo215         573
# tisztamo        497
# caseywschmid    456
# i-a-n           289
#                ...
# AshminJayson      1
# caryden           1
# yipkaiwing        1
# pray92            1
# MrAAafa99         1
# Name: count, Length: 1554, dtype: int64

# %%
top_10_authors = df["Author"].value_counts().head(10).reset_index()
top_10_authors.columns = ["Author", "Count"]
plt.figure(figsize=(6, 4))
sns.catplot(x="Author", y="Count", kind="bar", data=top_10_authors, height=5, aspect=2)
plt.xticks(rotation=45)
plt.title('Top 10 Authors')
plt.show()

# %%
df['RepoName'].value_counts().sort_index()
# Out:
# RepoName
#                                         954
# 0x79de/0x79de.github.io                   1
# 10-Kirito/Notes                           5
# 152334H/152334H.github.io                 1
# 1766left/EasyFill                         9
#                                        ...
# zmaril/multirender                       10
# zsviczian/obsidian-excalidraw-plugin      3
# zudsniper/learn_from_cgpt                12
# zumatt/personalWebsite                    7
# zyhzsh/S7-Doc                            28
# Name: count, Length: 1480, dtype: int64

# %%
df['RepoLanguage'].value_counts()
# Out:
# RepoLanguage
# CSS         4162
# HTML        1953
# Python      1908
# C#          1051
# C++          981
#             ...
# APL            1
# Mustache       1
# MDX            1
# Groovy         1
# Nim            1
# Name: count, Length: 72, dtype: int64

# %%
df['RepoLanguage'].unique()
# Out:
# array(['HTML', 'CSS', 'JavaScript', 'Python', 'Batchfile', None, 'Lua',
#        'Jinja', 'Shell', 'Java', 'C', 'Dockerfile', 'C#', 'Pascal', 'Go',
#        'EJS', 'GAML', 'Cython', '', 'TypeScript', 'Jupyter Notebook',
#        'Vue', 'PHP', 'Kotlin', 'C++', 'Solidity', 'Emacs Lisp', 'F#',
#        'Dart', 'MDX', 'PowerShell', 'Assembly', 'ASL', 'APL',
#        'API Blueprint', 'ANTLR', 'CodeQL', 'R', 'Astro', 'Rust', 'PLSQL',
#        'PLpgSQL', 'Haskell', 'GLSL', 'MATLAB', 'Procfile', 'Makefile',
#        'HCL', 'Awk', 'ShaderLab', 'AutoHotkey', 'Julia', 'Apex', 'TeX',
#        'Qt Script', 'Swift', 'Asymptote', 'Clojure', 'Mustache', 'NASL',
#        'Coq', 'Nix', 'Nunjucks', 'AppleScript', 'Ruby', 'Verilog', 'Perl',
#        'Game Maker Language', 'Zig', 'Objective-C', 'Groovy', 'Nim',
#        'SystemVerilog'], dtype=object)

# %%
top_15_languages = df["RepoLanguage"].value_counts().head(15).reset_index()
top_15_languages.columns = ["RepoLanguage", "Count"]
top_15_languages = top_15_languages.sort_values(by='Count', ascending=True)

plt.figure(figsize=(12, 6))
sns.barplot(x="Count", y="RepoLanguage", data=top_15_languages)

plt.title('Top 15 Repo Languages', fontsize=14)
plt.xlabel('Count')
plt.ylabel('Repo Language')

plt.show()

# %%
df['NumPrompts'].value_counts().sort_index()
# Out:
# NumPrompts
# 1      1416
# 2       622
# 3       684
# 4       701
# 5       655
#        ...
# 117     116
# 167     166
# 290     289
# 302     301
# 574     573
# Name: count, Length: 78, dtype: int64

# %%
df['ModelUsed'].value_counts()
# Out:
# ModelUsed
# Default (GPT-3.5)         6888
# GPT-4                     6526
# Advanced Data Analysis    2041
# Plugins                   2010
# Default                    466
# Web Browsing               221
# Model: Default              11
# Name: count, dtype: int64

# %% [markdown]
# The prompt counts and model usage seems interesting, let's plot these to see the actual distributions

# %%
# don't make the same mistake of using the entire dataset and subset it first
df_prompts = df[['NumPrompts']]

alt.data_transformers.disable_max_rows()

alt.Chart(df_prompts).mark_bar().encode(
    x = alt.X('NumPrompts', bin = alt.Bin(maxbins = 20), title = 'Number of Prompts'),
    y = alt.Y('count()', title = 'Count')
)
# Out:
# alt.Chart(...)

# %% [markdown]
# Most converstaions are limited to 100 prompts at most, but there are some interesting outliers that may be worth diving into more.

# %%
df_model = df[['ModelUsed']]

alt.Chart(df_model).mark_bar().encode(
    x = alt.X('count()', title = 'Count'),
    y = alt.Y('ModelUsed:N', title = 'Model', sort = 'x')
)
# Out:
# alt.Chart(...)

# %% [markdown]
# I wonder if there's a relationship between the number of prompts and the model used? This might be difficult to figure out since there are clearly two dominant models, but it might be worth exploring. Additionally, it might be worth figuring out if the higher tier models are actually better and compare the answer to prompts depending on the model. Building on this further, we can evaluate the 'quality' of responses depending on the model.

# %% [markdown]
# ##### Research Question: How do GPT answers vary based on the model used? Is there specific language or vocabulary that differs between each model? Do the answer lengths differ?

# %% [markdown]
# Let's subset the data to only focus on the model, prompts, and answers

# %%
df_rq1 = df[['ModelUsed', 'Prompt', 'Answer']]

df_rq1.head()
# Out:
#                 ModelUsed                                             Prompt  \
# 0       Default (GPT-3.5)  このコードだと、スマートフォンでキーボードを表示したときにbuttonがキーボードの下に隠れ...
# 1                 Default  このコードなんですが、Placeholder上でちゃんと改行するコードにできますか。\n\n...
# 2                 Default  refactor this code.\n\n<!DOCTYPE html>\n<html>...
# 3  Advanced Data Analysis  server.js\n// Required libraries\nimport cors ...
# 4  Advanced Data Analysis  package.json\n{\n  "name": "mindfulai",\n  "ve...
#
#                                               Answer
# 0  ChatGPTキーボードが表示されたときにボタンをキーボードの上に移動させるには、CSSでキ...
# 1  ChatGPTはい、改行を含むPlaceholder文字列を設定するコードを作成することがで...
# 2  ChatGPTHere's a refactored version of your HTM...
# 3  ChatGPTYou've shared multiple pieces of server...
# 4  ChatGPTIt looks like you're having issues with...

# %% [markdown]
# First, let's combine all the default models into one category

# %%
df_rq1.loc[:, 'ModelUsed'] = df_rq1['ModelUsed'].replace(
    ['Model: Default', 'Default'], 'Default (GPT-3.5)'
)

df_rq1.head()
# Out:
#                 ModelUsed                                             Prompt  \
# 0       Default (GPT-3.5)  このコードだと、スマートフォンでキーボードを表示したときにbuttonがキーボードの下に隠れ...
# 1       Default (GPT-3.5)  このコードなんですが、Placeholder上でちゃんと改行するコードにできますか。\n\n...
# 2       Default (GPT-3.5)  refactor this code.\n\n<!DOCTYPE html>\n<html>...
# 3  Advanced Data Analysis  server.js\n// Required libraries\nimport cors ...
# 4  Advanced Data Analysis  package.json\n{\n  "name": "mindfulai",\n  "ve...
#
#                                               Answer
# 0  ChatGPTキーボードが表示されたときにボタンをキーボードの上に移動させるには、CSSでキ...
# 1  ChatGPTはい、改行を含むPlaceholder文字列を設定するコードを作成することがで...
# 2  ChatGPTHere's a refactored version of your HTM...
# 3  ChatGPTYou've shared multiple pieces of server...
# 4  ChatGPTIt looks like you're having issues with...

# %% [markdown]
# For interpretability, we will also remove non-english prompts/answers. Additionally, we will remove 'ChatGPT' at the start of each answer as this will skew results if we care about word counts/frequencies.

# %%
def is_english(text):
    try:
        return detect(text) == 'en'
    except:
        return False

# filter on prompt and answer columns, also remove ChatGPT from the start of Answer
df_rq1_filtered = df_rq1[df_rq1['Prompt'].apply(is_english) & df_rq1['Answer'].apply(is_english)]
df_rq1_filtered.loc[:, 'Answer'] = df_rq1_filtered['Answer'].str.replace(r'^ChatGPT', '', regex  = True)

df_rq1_filtered.head()
# Out:
#                 ModelUsed                                             Prompt  \
# 2       Default (GPT-3.5)  refactor this code.\n\n<!DOCTYPE html>\n<html>...
# 3  Advanced Data Analysis  server.js\n// Required libraries\nimport cors ...
# 4  Advanced Data Analysis  package.json\n{\n  "name": "mindfulai",\n  "ve...
# 5  Advanced Data Analysis  \n/home/bitnami/.pm2/logs/Mindful-AI-out-0.log...
# 6  Advanced Data Analysis  \n/home/bitnami/.pm2/logs/Mindful-AI-out-0.log...
#
#                                               Answer
# 2  Here's a refactored version of your HTML and J...
# 3  You've shared multiple pieces of server code t...
# 4  It looks like you're having issues with your s...
# 5  From the logs and the code you provided, there...
# 6  The logs indicate two main issues:The module P...

# %%
df_rq1_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14311 entries, 2 to 27092
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ModelUsed  14311 non-null  object
#  1   Prompt     14311 non-null  object
#  2   Answer     14311 non-null  object
# dtypes: object(3)
# memory usage: 447.2+ KB

# %% [markdown]
# Let's take a high-level look at models and answers provided, specifically on the average word counts by model. To do this, we will need to perform some extra cleaning, removing punctuation from the text.

# %%
def clean_answer(answer):

    # keep contractions good
    answer = re.sub(r"(?<=\w)'(?=\w)", "", answer)
    # take out punctuation, add space
    answer = re.sub(r"[.,;!?:]", " ", answer)
    # deal with any additional symbols, characters, etc.
    answer = re.sub(r"[^\w\s]", "", answer)
    answer = answer.lower()

    return answer

df_rq1_filtered.loc[:, 'Answer'] = df_rq1_filtered['Answer'].apply(clean_answer)

df_rq1_filtered.head()
# Out:
#                 ModelUsed                                             Prompt  \
# 2       Default (GPT-3.5)  refactor this code.\n\n<!DOCTYPE html>\n<html>...
# 3  Advanced Data Analysis  server.js\n// Required libraries\nimport cors ...
# 4  Advanced Data Analysis  package.json\n{\n  "name": "mindfulai",\n  "ve...
# 5  Advanced Data Analysis  \n/home/bitnami/.pm2/logs/Mindful-AI-out-0.log...
# 6  Advanced Data Analysis  \n/home/bitnami/.pm2/logs/Mindful-AI-out-0.log...
#
#                                               Answer
# 2  heres a refactored version of your html and ja...
# 3  youve shared multiple pieces of server code th...
# 4  it looks like youre having issues with your se...
# 5  from the logs and the code you provided  there...
# 6  the logs indicate two main issues the module p...

# %% [markdown]
# Now that the answer column should be mostly clean, we can start doing some analysis. Let's start with word counts, a simple metric to calculate.

# %%
df_rq1_clean = df_rq1_filtered.copy()
df_rq1_clean.loc[:, 'WordCount'] = df_rq1_clean['Answer'].apply(lambda x: len(x.split()))

df_rq1_clean.head()
# Out:
#                 ModelUsed                                             Prompt  \
# 2       Default (GPT-3.5)  refactor this code.\n\n<!DOCTYPE html>\n<html>...
# 3  Advanced Data Analysis  server.js\n// Required libraries\nimport cors ...
# 4  Advanced Data Analysis  package.json\n{\n  "name": "mindfulai",\n  "ve...
# 5  Advanced Data Analysis  \n/home/bitnami/.pm2/logs/Mindful-AI-out-0.log...
# 6  Advanced Data Analysis  \n/home/bitnami/.pm2/logs/Mindful-AI-out-0.log...
#
#                                               Answer  WordCount
# 2  heres a refactored version of your html and ja...         85
# 3  youve shared multiple pieces of server code th...        514
# 4  it looks like youre having issues with your se...        343
# 5  from the logs and the code you provided  there...        266
# 6  the logs indicate two main issues the module p...        260

# %%
summary_stats = df_rq1_clean.groupby('ModelUsed')['WordCount'].agg(
    mean = 'mean',
    median = 'median',
    min = 'min',
    max = 'max',
    std = 'std',
    count = 'count'
).reset_index()

summary_stats
# Out:
#                 ModelUsed        mean  median  min   max         std  count
# 0  Advanced Data Analysis  200.718246   164.0    1  1785  163.096975   1551
# 1       Default (GPT-3.5)  166.470061   133.0    1  2478  136.432237   5695
# 2                   GPT-4  161.876421   140.0    1   785  121.566580   5365
# 3                 Plugins  176.833659   154.0    1  1290  122.315472   1533
# 4            Web Browsing  224.562874   182.0   23  1039  169.818704    167

# %% [markdown]
# We can see that GPT-4 responses have a lot less variance and overall, have a lower word count. The default model, 3.5, has a large range of values, but web browsing and advanced data anlysis, on average, have larger word counts for responses.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_rq1_clean, x='ModelUsed', y='WordCount', palette='Set2')

# Add labels and title
plt.xlabel('Model Used')
plt.ylabel('Word Count')
plt.title('Word Count Distribution by Model')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_19604\1000061320.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_rq1_clean, x='ModelUsed', y='WordCount', palette='Set2')

# %% [markdown]
# ### What types of issues (bugs, feature requests, theoretical questions, etc.) do developers most commonly present to ChatGPT?

# %% [markdown]
# #### Firstly, decide the keywords of different types of issues

# %%
keyword_categories = {
    "Bug Reports": ["error", "bug", "crash", "exception", "fail", "issue", "fix"],
    "Feature Requests": ["feature", "enhance", "add support", "improve", "implement"],
    "Theoretical Questions": ["explain", "theory", "why", "difference", "how does"],
    "Performance Issues": ["slow", "optimize", "bottleneck", "latency", "performance"],
    "Code Help": ["how to", "example", "sample", "syntax", "help", "debug"]
}

# %% [markdown]
# #### Secondly, clean Prompt

# %%
def clean_prompt(prompt):

    # keep contractions good
    answer = re.sub(r"(?<=\w)'(?=\w)", "", prompt)
    # take out punctuation, add space
    answer = re.sub(r"[.,;!?:]", " ", prompt)
    # deal with any additional symbols, characters, etc.
    answer = re.sub(r"[^\w\s]", "", prompt)
    answer = answer.lower()

    return answer

df_rq1_clean_new = df_rq1_clean.copy()
df_rq1_clean_new.loc[:, 'Prompt'] = df_rq1_clean_new['Prompt'].apply(clean_answer)

df_rq1_clean_new.head()
# Out:
#                 ModelUsed                                             Prompt  \
# 2       Default (GPT-3.5)  refactor this code \n\n doctype html\nhtml\n  ...
# 3  Advanced Data Analysis  server js\n required libraries\nimport cors fr...
# 4  Advanced Data Analysis  package json\n\n  name  mindfulai \n  version ...
# 5  Advanced Data Analysis  \nhomebitnami pm2logsmindfulaiout0 log last 15...
# 6  Advanced Data Analysis  \nhomebitnami pm2logsmindfulaiout0 log last 15...
#
#                                               Answer  WordCount
# 2  heres a refactored version of your html and ja...         85
# 3  youve shared multiple pieces of server code th...        514
# 4  it looks like youre having issues with your se...        343
# 5  from the logs and the code you provided  there...        266
# 6  the logs indicate two main issues the module p...        260

# %%
def count_keywords(text, category_keywords):
    text = text.lower() if isinstance(text, str) else ""
    return sum(text.count(keyword) for keyword in category_keywords)

category_counts = {category: 0 for category in keyword_categories}
for category, keywords in keyword_categories.items():
    category_counts[category] += df["Prompt"].apply(lambda x: count_keywords(x, keywords)).sum()
    category_counts[category] += df["Answer"].apply(lambda x: count_keywords(x, keywords)).sum()

# %%
category_df = pd.DataFrame(category_counts.items(), columns=["Issue Type", "Count"])
category_df.sort_values('Count')
category_df
# Out:
#               Issue Type  Count
# 0            Bug Reports  22203
# 1       Feature Requests  12170
# 2  Theoretical Questions   3478
# 3     Performance Issues   2652
# 4              Code Help  19659

# %%
category_df = pd.DataFrame(category_counts.items(), columns=["Issue Type", "Count"])
category_df = category_df.sort_values('Count')

plt.figure(figsize=(8, 5))
    
plt.barh(category_df["Issue Type"], category_df["Count"])
plt.xlabel("Keyword Frequency")
plt.ylabel("Issue Type")
plt.title("Common Types of Issues Presented to ChatGPT")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ### How many turns does it take on average to reach a conclusion? What is the typical structure of conversations between developers and ChatGPT?

# %%
mean_turns = df["NumPrompts"].mean()
median_turns = df["NumPrompts"].median()
mode_turns = df["NumPrompts"].mode()[0]

print(f"Mean NumPrompts: {mean_turns:.2f}")
print(f"Median NumPrompts: {median_turns}")
print(f"Most common NumPrompts (Mode): {mode_turns}")
# Out:
# Mean NumPrompts: 51.15
# Median NumPrompts: 17.0
# Most common NumPrompts (Mode): 1

# %% [markdown]
# The mean number of prompts per conversation is 51.15, which suggests that interactions tend to be long and multi-turn.

# %%
top_NumPrompts = df["NumPrompts"].value_counts().head(10).reset_index()
top_NumPrompts.columns = ["NumPrompts", "Count"]
top_NumPrompts["NumPrompts"] = top_NumPrompts["NumPrompts"].astype(str) 
top_NumPrompts = top_NumPrompts.sort_values(by="Count", ascending=False)

plt.figure(figsize=(8, 5))
sns.barplot(x="NumPrompts", y="Count", data=top_NumPrompts, palette="Blues_r")
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_19604\2602114733.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="NumPrompts", y="Count", data=top_NumPrompts, palette="Blues_r")

# %%
# df['NumPrompts'].hist(bins=20)
plt.hist(df['NumPrompts'], bins=30)
plt.show()
