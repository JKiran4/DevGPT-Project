# %%
import os
import pandas as pd

# %%
# don't have to run this every time! re-import the exported csv to save time.

dirs = [("DevGPT/" + d) for d in os.listdir("DevGPT") if os.path.isdir("DevGPT/" + d)] # modify this to limit snapshots

files = []
for dir in dirs:
    for f in os.listdir(dir):
        if f[-5:] == ".json": files.append(dir + "/" + f)

print(files)

imports = []
for f in files:
    if f[-5:] == ".json":  # this one pulls all files
        trydf = pd.read_json(f)
        trydf = pd.json_normalize(trydf["Sources"])
        trydf["filepath"] = f
        imports.append(trydf)

df = pd.concat(imports, ignore_index = True)
df.to_csv("df-export.csv", index = False)

# %%
dfi = pd.read_csv("df-export.csv")

# %%
hn_q = "filepath.str.contains('hn_sharings.json')"
pr_q = "filepath.str.contains('pr_sharings.json')"
is_q = "filepath.str.contains('issue_sharings.json')"
di_q = "filepath.str.contains('discussion_sharings.json')"
co_q = "filepath.str.contains('commit_sharings.json')"
fi_q = "filepath.str.contains('file_sharings.json')"

dfi.query(di_q)
# Out:
#             Type  ID                                                URL  \
# 520   discussion NaN  https://github.com/orgs/deep-foundation/discus...
# 521   discussion NaN  https://github.com/JushBJJ/Mr.-Ranedeer-AI-Tut...
# 522   discussion NaN  https://github.com/dtch1997/gpt-text-gym/discu...
# 523   discussion NaN  https://github.com/dave1010/pandora/discussions/6
# 524   discussion NaN     https://github.com/sugi-01096/72/discussions/2
# ...          ...  ..                                                ...
# 9015  discussion NaN  https://github.com/DirectoryTree/LdapRecord-La...
# 9016  discussion NaN  https://github.com/uuid6/prototypes/discussion...
# 9017  discussion NaN  https://github.com/manticoresoftware/manticore...
# 9018  discussion NaN  https://github.com/SSWConsulting/SSW.Rules.Con...
# 9019  discussion NaN    https://github.com/orgs/netket/discussions/1482
#
#               Author  Points AttachedURL  \
# 520   FreePhoenix888     NaN         NaN
# 521          JushBJJ     NaN         NaN
# 522         dtch1997     NaN         NaN
# 523         dave1010     NaN         NaN
# 524       haruto0214     NaN         NaN
# ...              ...     ...         ...
# 9015          D3llon     NaN         NaN
# 9016     kyzer-davis     NaN         NaN
# 9017            l1t1     NaN         NaN
# 9018     lukecookssw     NaN         NaN
# 9019       MrAAafa99     NaN         NaN
#
#                                                   Title StoryText  \
# 520   Should we worry about imports perfomance in ha...       NaN
# 521                   v2.7 - Code Interpreter Exclusive       NaN
# 522            GPT decomposing missions using functions       NaN
# 523   Demo and examples thread. Share what you've do...       NaN
# 524                                                   a       NaN
# ...                                                 ...       ...
# 9015  LDAP authentication using IIS Application pool...       NaN
# 9016  Name for UUID with all bits set to 1 (FFFFFFFF...       NaN
# 9017           how to install on proot ubuntu of termux       NaN
# 9018  2023-06-9 - Databases, data warehouses, and da...       NaN
# 9019  Exploring the Plotting of Pair Correlation Fun...       NaN
#
#                  CreatedAt  CommentsTotalCount  ... UpvoteCount  Sha Message  \
# 520   2023-07-11T11:31:00Z                 NaN  ...         1.0  NaN     NaN
# 521   2023-07-15T10:58:10Z                 NaN  ...         1.0  NaN     NaN
# 522   2023-06-26T19:30:34Z                 NaN  ...         1.0  NaN     NaN
# 523   2023-07-02T14:56:52Z                 NaN  ...         1.0  NaN     NaN
# 524   2023-06-13T09:24:10Z                 NaN  ...         1.0  NaN     NaN
# ...                    ...                 ...  ...         ...  ...     ...
# 9015  2023-05-29T10:47:04Z                 NaN  ...         2.0  NaN     NaN
# 9016  2023-06-07T15:06:44Z                 NaN  ...         5.0  NaN     NaN
# 9017  2023-07-22T12:20:22Z                 NaN  ...         1.0  NaN     NaN
# 9018  2023-06-08T05:45:47Z                 NaN  ...         1.0  NaN     NaN
# 9019  2023-05-25T15:11:27Z                 NaN  ...         1.0  NaN     NaN
#
#      AuthorAt  CommitAt ObjectSha FileName FilePath Content CommitMessage
# 520       NaN       NaN       NaN      NaN      NaN     NaN           NaN
# 521       NaN       NaN       NaN      NaN      NaN     NaN           NaN
# 522       NaN       NaN       NaN      NaN      NaN     NaN           NaN
# 523       NaN       NaN       NaN      NaN      NaN     NaN           NaN
# 524       NaN       NaN       NaN      NaN      NaN     NaN           NaN
# ...       ...       ...       ...      ...      ...     ...           ...
# 9015      NaN       NaN       NaN      NaN      NaN     NaN           NaN
# 9016      NaN       NaN       NaN      NaN      NaN     NaN           NaN
# 9017      NaN       NaN       NaN      NaN      NaN     NaN           NaN
# 9018      NaN       NaN       NaN      NaN      NaN     NaN           NaN
# 9019      NaN       NaN       NaN      NaN      NaN     NaN           NaN
#
# [234 rows x 37 columns]
